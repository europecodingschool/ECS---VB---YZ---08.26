# %% [markdown]
# <a href="https://colab.research.google.com/github/europecodingschool/ECS---VB---YZ---08.26/blob/main/VB_YZ_Ders_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INTRO - BAŞLANGIÇ**

# %%
2
# Out:
# 2

# %%
2 + 5
# Out:
# 7

# %%
3 * 5
# Out:
# 15

# %% [markdown]
# # **variables - değişkenler**

# %%
800 / 4
# Out:
# 200.0

# %%
649 / 5
# Out:
# 129.8

# %%
10 - 90
# Out:
# -80

# %%
age = 10

# %%
age
# Out:
# 10

# %%
age + 5
# Out:
# 15

# %%
age / 4
# Out:
# 2.5

# %%
age + age
# Out:
# 20

# %%
age = 15

# %%
age + 5
# Out:
# 20

# %%
age * 4
# Out:
# 60

# %%
x = 10
y = 4

# %%
x
# Out:
# 10

# %%
y
# Out:
# 4

# %%
x + 5 + y + 4 + 6 #toplama işlemi
# Out:
# 29
