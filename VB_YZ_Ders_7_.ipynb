# %% [markdown]
# <a href="https://colab.research.google.com/github/europecodingschool/ECS---VB---YZ---08.26/blob/main/VB_YZ_Ders_7_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Kütüphanelerin YÜklenmesi **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **2. Veri Setinin Yüklenmesi**

# %%
df_train = pd.read_csv("/content/train.csv")
df_test = pd.read_csv("/content/test.csv")

# %% [markdown]
# **3. Keşifsel Veri Analizi (EDA)**

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
df = pd.concat((df_train,df_test), sort=False, ignore_index=True) # iki ayrı .csv dosyasını birleştirdik.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1304         1305       NaN       3            Spector, Mr. Woolf    male
# 1305         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308       NaN       3           Ware, Mr. Frederick    male
# 1308         1309       NaN       3      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 1304   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  39.0      0      0            PC 17758  108.9000  C105        C
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307   NaN      0      0              359309    8.0500   NaN        S
# 1308   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# ![Ekran Resmi 2026-08-27 20.45.08.png](data:image/png;base64,...)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
df.isnull().sum() #eksik veri adetlerini görme.
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
df[:891] #ilk 891 veri
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[891:] #son 418 data (test.csv dataları birleşmeden önce)
# Out:
#       PassengerId  Survived  Pclass  \
# 891           892       NaN       3
# 892           893       NaN       3
# 893           894       NaN       2
# 894           895       NaN       3
# 895           896       NaN       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                               Name     Sex   Age  SibSp  \
# 891                               Kelly, Mr. James    male  34.5      0
# 892               Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 893                      Myles, Mr. Thomas Francis    male  62.0      0
# 894                               Wirz, Mr. Albert    male  27.0      0
# 895   Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ...                                            ...     ...   ...    ...
# ...

# %%
df_train.shape #satır ve sütun adetleri
# Out:
# (891, 12)

# %%
df_test.shape #satır ve sütun adetleri
# Out:
# (418, 11)

# %%
df.shape #satır ve sütun adetleri
# Out:
# (1309, 12)

# %%
print(df.duplicated().sum()) #tekrar eden verimiz var mı satır olarak ona baktık.
# Out:
# 0

# %%
df.nunique() #uniq,eşsiz değerlere bakıyoruz.
# Out:
# PassengerId    1309
# Survived          2
# Pclass            3
# Name           1307
# Sex               2
# Age              98
# SibSp             7
# Parch             8
# Ticket          929
# Fare            281
# Cabin           186
# Embarked          3
# dtype: int64

# %%
df.nunique().sort_values() # sort_values() eklediğimizde sıralayarak getiriyor. Daha rahat görmemizi sağlıyor.
# Out:
# Survived          2
# Sex               2
# Pclass            3
# Embarked          3
# SibSp             7
# Parch             8
# Age              98
# Cabin           186
# Fare            281
# Ticket          929
# Name           1307
# PassengerId    1309
# dtype: int64

# %%
#Kategorik - az sayıda farklı değer varsa - (Survived,Sex,Pclass,Embarked,SibSp,Parch)
#Sayısal - çok sayıda farklı değer varsa ve sayıysa - Age, Fare
#kardinal - çok sayıda farklı ve metinsel - Name,Ticket,Cabin
#kimlik - her satır farklıysa bir numaraysa - PassengerId

# %%
df["Age"].hist(bins=15, figsize=(10,5))
# Out:
# <Axes: >

# %%
len(df[df['Age']>=30])
# Out:
# 477

# %%
len(df[df['Age']<30])
# Out:
# 569

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0.0    549
# 1.0    342
# Name: count, dtype: int64

# %%
df["Survived"].value_counts(normalize=True)
# Out:
# Survived
# 0.0    0.616162
# 1.0    0.383838
# Name: proportion, dtype: float64

# %%
df["Survived"].value_counts(normalize=True).plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %%
#bar grafiği x ekseninde survive y adetler
df["Survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
df.groupby("Sex")['Survived'].value_counts()
# Out:
# Sex     Survived
# female  1.0         233
#         0.0          81
# male    0.0         468
#         1.0         109
# Name: count, dtype: int64

# %%
df.groupby("Sex")['Survived'].value_counts(normalize=True)
# Out:
# Sex     Survived
# female  1.0         0.742038
#         0.0         0.257962
# male    0.0         0.811092
#         1.0         0.188908
# Name: proportion, dtype: float64

# %%
df["Survived"].groupby(df['Sex']).value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Sex,Survived'>

# %%
#seaborn ile daha güzel görünen bir grafik
sns.countplot(x='Sex',
              hue='Survived',
              data=df)
plt.xlabel('cinsiyet')
plt.ylabel('kişi Sayısı')
# Out:
# Text(0, 0.5, 'kişi Sayısı')

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
df["Pclass"].value_counts(normalize=True)
# Out:
# Pclass
# 3    0.541635
# 1    0.246753
# 2    0.211612
# Name: proportion, dtype: float64

# %%
#Sınıfların içinde kaş kişi hayatta kaç kişi ölmüş buna bakacağız.
df['Survived'].groupby(df['Pclass']).value_counts()
# Out:
# Pclass  Survived
# 1       1.0         136
#         0.0          80
# 2       0.0          97
#         1.0          87
# 3       0.0         372
#         1.0         119
# Name: count, dtype: int64

# %%
df['Survived'].groupby(df['Pclass']).value_counts(normalize=True)
# Out:
# Pclass  Survived
# 1       1.0         0.629630
#         0.0         0.370370
# 2       0.0         0.527174
#         1.0         0.472826
# 3       0.0         0.757637
#         1.0         0.242363
# Name: proportion, dtype: float64

# %%
df['Survived'].groupby([df['Pclass'],df['Sex']]).value_counts()
# Out:
# Pclass  Sex     Survived
# 1       female  1.0          91
#                 0.0           3
#         male    0.0          77
#                 1.0          45
# 2       female  1.0          70
#                 0.0           6
#         male    0.0          91
#                 1.0          17
# 3       female  0.0          72
#                 1.0          72
#         male    0.0         300
#                 1.0          47
# Name: count, dtype: int64

# %%
olen_vıp_kadinlar = (df['Pclass']==1) & (df['Sex'] =='female') & (df['Survived']==0)

# %%
df[olen_vıp_kadinlar]
# Out:
#      PassengerId  Survived  Pclass  \
# 177          178       0.0       1
# 297          298       0.0       1
# 498          499       0.0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 177                       Isham, Miss. Ann Elizabeth  female  50.0      0
# 297                     Allison, Miss. Helen Loraine  female   2.0      1
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0      1
#
#      Parch    Ticket      Fare    Cabin Embarked
# 177      0  PC 17595   28.7125      C49        C
# 297      2    113781  151.5500  C22 C26        S
# 498      2    113781  151.5500  C22 C26        S

# %%
df['Survived'].groupby([df['Pclass'],df['Sex']]).value_counts(normalize=True)
# Out:
# Pclass  Sex     Survived
# 1       female  1.0         0.968085
#                 0.0         0.031915
#         male    0.0         0.631148
#                 1.0         0.368852
# 2       female  1.0         0.921053
#                 0.0         0.078947
#         male    0.0         0.842593
#                 1.0         0.157407
# 3       female  0.0         0.500000
#                 1.0         0.500000
#         male    0.0         0.864553
#                 1.0         0.135447
# Name: proportion, dtype: float64

# %% [markdown]
# ANALİZ
#
#
#
# *   Kadınlara kurtarma sırasında öncelik verildiği gözlemleniyor. Hem sınıfsal olarak hem de genel anlamda kadınların yaşama oranı daha yüksek.
# *   Verileri incelediğimizde net bir şekilde sınıfsal ayrım ortaya çıkmaktadır. Bilet tipi olarak üst sınıftaki insanların kurtulma oranının daha yüksek olduğu anlaşılmıştır.

# %%
sns.countplot(x='Survived',
              hue='Pclass',
              data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df_series = df['Survived'].groupby([df['Pclass'],df['Sex']]).value_counts()

# %%
type(df_series)
# Out:
# pandas.core.series.Series

# %%
df_series
# Out:
# Pclass  Sex     Survived
# 1       female  1.0          91
#                 0.0           3
#         male    0.0          77
#                 1.0          45
# 2       female  1.0          70
#                 0.0           6
#         male    0.0          91
#                 1.0          17
# 3       female  0.0          72
#                 1.0          72
#         male    0.0         300
#                 1.0          47
# Name: count, dtype: int64

# %%
df2 = df['Survived'].groupby([df['Pclass'],df['Sex']]).value_counts().reset_index(name='count')

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2
# Out:
#     Pclass     Sex  Survived  count
# 0        1  female       1.0     91
# 1        1  female       0.0      3
# 2        1    male       0.0     77
# 3        1    male       1.0     45
# 4        2  female       1.0     70
# 5        2  female       0.0      6
# 6        2    male       0.0     91
# 7        2    male       1.0     17
# 8        3  female       0.0     72
# 9        3  female       1.0     72
# 10       3    male       0.0    300
# 11       3    male       1.0     47

# %%
sns.catplot(data=df2,
            x="Pclass",
            y="count",
            hue="Survived",
            col="Sex",
            kind="bar")
plt.show()

# %%
sns.histplot(data=df,
             x='Age',
             hue='Survived',
             bins=10,
             multiple='dodge',
             kde=True)
plt.show()

# %%
df['Age'].describe() # Yaş ile ilgili istatistikler
# Out:
# count    1046.000000
# mean       29.881138
# std        14.413493
# min         0.170000
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
df_cocuk = df[df['Age'] <=15] # 15 yaşında altında olanları çocuk olarak nitelendirdik.

# %%
df_cocuk
# Out:
#       PassengerId  Survived  Pclass                                  Name  \
# 7               8       0.0       3        Palsson, Master. Gosta Leonard
# 9              10       1.0       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10             11       1.0       3       Sandstrom, Miss. Marguerite Rut
# 14             15       0.0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 16             17       0.0       3                  Rice, Master. Eugene
# ...           ...       ...     ...                                   ...
# 1251         1252       NaN       3           Sage, Master. William Henry
# 1270         1271       NaN       3           Asplund, Master. Carl Edgar
# 1280         1281       NaN       3           Palsson, Master. Paul Folke
# 1283         1284       NaN       3         Abbott, Master. Eugene Joseph
# 1300         1301       NaN       3             Peacock, Miss. Treasteall
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %%
df_cocuk.shape
# Out:
# (115, 12)

# %%
df_cocuk.groupby('Pclass')['Survived'].value_counts()
# Out:
# Pclass  Survived
# 1       1.0          5
#         0.0          1
# 2       1.0         19
# 3       0.0         33
#         1.0         25
# Name: count, dtype: int64

# %%
df_cocuk.groupby('Pclass')['Survived'].value_counts(normalize=True)
# Out:
# Pclass  Survived
# 1       1.0         0.833333
#         0.0         0.166667
# 2       1.0         1.000000
# 3       0.0         0.568966
#         1.0         0.431034
# Name: proportion, dtype: float64

# %% [markdown]
# **Analiz**
# Sınıflara Göre Çocukların Durumu
# 1. Sınıf (Pclass 1): Bu sınıftaki çocukların yaklaşık %83.3'ü hayatta kalmış (1.0), %16.7'si ise maalesef hayatını kaybetmiş (0.0). Birinci sınıf yolcuların filikalara erişim avantajı çocuklara da yansımış.
#
# 2. Sınıf (Pclass 2): Tablodaki en dikkat çekici detaylardan biri burası. 2. sınıfta seyahat eden 15 yaş altı çocukların %100'ü hayatta kalmış (1.0). Tabloda (0.0) değerinin hiç çıkmaması, bu sınıftaki hiçbir çocuğun ölmediğini gösteriyor.
#
# 3. Sınıf (Pclass 3): Tablonun en acı verici kısmı maalesef 3. sınıf. Bu sınıftaki çocukların %56.9'u hayatını kaybetmiş (0.0). Hayatta kalma oranları ise sadece %43.1 (1.0) seviyesinde kalmış.
#
# Sosyal Eşitsizlik ve Gemi Düzeni
# Bu analiz bize şunu çok net söylüyor: Titanic'te tahliye sırasında meşhur "önce kadınlar ve çocuklar" kuralı uygulanmış olsa da, bu kural sosyal sınıf gerçeğinin önüne geçememiş.
#
# ve 2. sınıf yolcular geminin üst güvertelerinde, yani filikalara en yakın konumlarda seyahat ediyorlardı. Tahliye anında bilgiye ve cankurtaran sandallarına çok daha hızlı ulaştılar. Ancak 3. sınıf yolcular geminin en alt kısımlarındaydı. Hem labirent gibi koridorlardan yukarı çıkmak zorundaydılar hem de kilitli kapılar gibi engellerle karşılaştılar. Bu fiziksel dezavantaj, 3. sınıftaki çocukların yarısından fazlasının kurtarılamamasına neden olmuş.

# %%
df['SibSp'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SibSp'>

# %%
df['Survived'].groupby(df['SibSp']).value_counts()
# Out:
# SibSp  Survived
# 0      0.0         398
#        1.0         210
# 1      1.0         112
#        0.0          97
# 2      0.0          15
#        1.0          13
# 3      0.0          12
#        1.0           4
# 4      0.0          15
#        1.0           3
# 5      0.0           5
# 8      0.0           7
# Name: count, dtype: int64

# %%
df['Survived'].groupby(df['SibSp']).value_counts(normalize=True)
# Out:
# SibSp  Survived
# 0      0.0         0.654605
#        1.0         0.345395
# 1      1.0         0.535885
#        0.0         0.464115
# 2      0.0         0.535714
#        1.0         0.464286
# 3      0.0         0.750000
#        1.0         0.250000
# 4      0.0         0.833333
#        1.0         0.166667
# 5      0.0         1.000000
# 8      0.0         1.000000
# Name: proportion, dtype: float64

# %%
df['family_size'] = df['SibSp'] + df['Parch']
df['family_size']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    2
# Name: family_size, Length: 1309, dtype: int64

# %%
df_alone =df[df['family_size']==0] # Yanlız yolculuk yapanlar.
df_alone,len(df_alone)
# Out:
# (      PassengerId  Survived  Pclass                            Name     Sex  \
#  2               3       1.0       3          Heikkinen, Miss. Laina  female
#  4               5       0.0       3        Allen, Mr. William Henry    male
#  5               6       0.0       3                Moran, Mr. James    male
#  6               7       0.0       1         McCarthy, Mr. Timothy J    male
#  11             12       1.0       1        Bonnell, Miss. Elizabeth  female
#  ...           ...       ...     ...                             ...     ...
#  1303         1304       NaN       3  Henriksson, Miss. Jenny Lovisa  female
#  1304         1305       NaN       3              Spector, Mr. Woolf    male
#  1305         1306       NaN       1    Oliva y Ocana, Dona. Fermina  female
#  1306         1307       NaN       3    Saether, Mr. Simon Sivertsen    male
#  1307         1308       NaN       3             Ware, Mr. Frederick    male
#
# ...

# %%
df_alone['Survived'].value_counts()
# Out:
# Survived
# 0.0    374
# 1.0    163
# Name: count, dtype: int64

# %%
df_alone['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0.0    0.696462
# 1.0    0.303538
# Name: proportion, dtype: float64

# %%
df_notalone = df[(df['SibSp']>0) | (df['Parch']>0)]

# %%
df_notalone # Yanlız yolculuk yapmayanlar
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 3               4       1.0       1
# 7               8       0.0       3
# 8               9       1.0       3
# ...           ...       ...     ...
# 1297         1298       NaN       2
# 1298         1299       NaN       1
# 1300         1301       NaN       3
# 1302         1303       NaN       1
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                        Palsson, Master. Gosta Leonard    male   2.0      3
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %%
df_notalone['Survived'].value_counts() # Yanlız yolculuk yapmayanlar
# Out:
# Survived
# 1.0    179
# 0.0    175
# Name: count, dtype: int64

# %%
df_notalone['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 1.0    0.50565
# 0.0    0.49435
# Name: proportion, dtype: float64

# %%
df_notalone.groupby('Pclass')['Survived'].value_counts(normalize=True)
# Out:
# Pclass  Survived
# 1       1.0         0.728972
#         0.0         0.271028
# 2       1.0         0.637500
#         0.0         0.362500
# 3       0.0         0.700599
#         1.0         0.299401
# Name: proportion, dtype: float64

# %%
df_alone.groupby('Pclass')['Survived'].value_counts(normalize=True)
# Out:
# Pclass  Survived
# 1       1.0         0.532110
#         0.0         0.467890
# 2       0.0         0.653846
#         1.0         0.346154
# 3       0.0         0.787037
#         1.0         0.212963
# Name: proportion, dtype: float64
