# %% [markdown]
# <a href="https://colab.research.google.com/github/europecodingschool/ECS---VB---YZ---08.26/blob/main/VB_YZ_Ders_5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Series **

# %%
notlar = {"Gürhan": 50, "Ayşe": 60, "Leyla":70}

# %%
notlar
# Out:
# {'Gürhan': 50, 'Ayşe': 60, 'Leyla': 70}

# %%
pd.Series(notlar)
# Out:
# Gürhan    50
# Ayşe      60
# Leyla     70
# dtype: int64

# %%
numpy_array = np.array([50,60,70,80])

# %%
numpy_array
# Out:
# array([50, 60, 70, 80])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    60
# 2    70
# 3    80
# dtype: int64

# %% [markdown]
# **Data Frame**

# %%
data = np.random.randint(10, size=(4,4))

# %%
data
# Out:
# array([[7, 0, 6, 2],
#        [5, 7, 5, 4],
#        [3, 8, 1, 0],
#        [9, 9, 3, 3]])

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#    0  1  2  3
# 0  7  0  6  2
# 1  5  7  5  4
# 2  3  8  1  0
# 3  9  9  3  3

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
data_frame[0]
# Out:
# 0    7
# 1    5
# 2    3
# 3    9
# Name: 0, dtype: int64

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
data_frame
# Out:
#    0  1  2  3
# 0  7  0  6  2
# 1  5  7  5  4
# 2  3  8  1  0
# 3  9  9  3  3

# %%
new_df = pd.DataFrame(data, index=["Gürhan","Ayşe","Elif","Melike"], columns = ["Ders1","Ders2", "Ders3","Ders4"])

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4
# Gürhan      7      0      6      2
# Ayşe        5      7      5      4
# Elif        3      8      1      0
# Melike      9      9      3      3

# %%
new_df['Ders1']
# Out:
# Gürhan    7
# Ayşe      5
# Elif      3
# Melike    9
# Name: Ders1, dtype: int64

# %%
new_df['Ders2']
# Out:
# Gürhan    0
# Ayşe      7
# Elif      8
# Melike    9
# Name: Ders2, dtype: int64

# %%
new_df['Ders3']
# Out:
# Gürhan    6
# Ayşe      5
# Elif      1
# Melike    3
# Name: Ders3, dtype: int64

# %%
# new_df['Gürhan']. - satır seçerken hata verir.

# %%
new_df.loc["Gürhan"]
# Out:
# Ders1    7
# Ders2    0
# Ders3    6
# Ders4    2
# Name: Gürhan, dtype: int64

# %%
new_df.loc["Elif"]
# Out:
# Ders1    3
# Ders2    8
# Ders3    1
# Ders4    0
# Name: Elif, dtype: int64

# %%
new_df.iloc[0]
# Out:
# Ders1    7
# Ders2    0
# Ders3    6
# Ders4    2
# Name: Gürhan, dtype: int64

# %%
new_df.iloc[1]
# Out:
# Ders1    5
# Ders2    7
# Ders3    5
# Ders4    4
# Name: Ayşe, dtype: int64

# %%
new_df.iloc[3]
# Out:
# Ders1    9
# Ders2    9
# Ders3    3
# Ders4    3
# Name: Melike, dtype: int64

# %%
new_df.loc[["Ayşe","Elif"]]
# Out:
#       Ders1  Ders2  Ders3  Ders4
# Ayşe      5      7      5      4
# Elif      3      8      1      0

# %%
new_df.loc["Gürhan":"Elif"]
# Out:
#         Ders1  Ders2  Ders3  Ders4
# Gürhan      7      0      6      2
# Ayşe        5      7      5      4
# Elif        3      8      1      0

# %%
new_df.iloc[0:2]
# Out:
#         Ders1  Ders2  Ders3  Ders4
# Gürhan      7      0      6      2
# Ayşe        5      7      5      4

# %%
new_df.iloc[0:3]
# Out:
#         Ders1  Ders2  Ders3  Ders4
# Gürhan      7      0      6      2
# Ayşe        5      7      5      4
# Elif        3      8      1      0

# %%
new_df.iloc[0:3,1:3]
# Out:
#         Ders2  Ders3
# Gürhan      0      6
# Ayşe        7      5
# Elif        8      1

# %% [markdown]
# **Data Manipülasyon - Satır Sütun Ekleme Çıkarma **

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4
# Gürhan      7      0      6      2
# Ayşe        5      7      5      4
# Elif        3      8      1      0
# Melike      9      9      3      3

# %%
new_df["Ders5"] = 8

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5
# Gürhan      7      0      6      2      8
# Ayşe        5      7      5      4      8
# Elif        3      8      1      0      8
# Melike      9      9      3      3      8

# %%
new_df["Ders5"] = [3,4,5,6]

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5
# Gürhan      7      0      6      2      3
# Ayşe        5      7      5      4      4
# Elif        3      8      1      0      5
# Melike      9      9      3      3      6

# %%
new_df["Ders6"] = [2,4,5,1]

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders6
# Gürhan      7      0      6      2      3      2
# Ayşe        5      7      5      4      4      4
# Elif        3      8      1      0      5      5
# Melike      9      9      3      3      6      1

# %%
new_df["Ders7"] = new_df["Ders3"] * 3

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders6  Ders7
# Gürhan      7      0      6      2      3      2     18
# Ayşe        5      7      5      4      4      4     15
# Elif        3      8      1      0      5      5      3
# Melike      9      9      3      3      6      1      9

# %%
new_df.drop("Ders7", axis=1) # Sütun silme axis parametresi 1 verildi. Sütun bazlı işlem için.
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders6
# Gürhan      7      0      6      2      3      2
# Ayşe        5      7      5      4      4      4
# Elif        3      8      1      0      5      5
# Melike      9      9      3      3      6      1

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders6  Ders7
# Gürhan      7      0      6      2      3      2     18
# Ayşe        5      7      5      4      4      4     15
# Elif        3      8      1      0      5      5      3
# Melike      9      9      3      3      6      1      9

# %%
new_df_2 = new_df.drop("Ders7", axis=1) # Sütun silme işlemini kaydetmek için yeni değişkene atadık.

# %%
new_df_2
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders6
# Gürhan      7      0      6      2      3      2
# Ayşe        5      7      5      4      4      4
# Elif        3      8      1      0      5      5
# Melike      9      9      3      3      6      1

# %%
new_df.drop("Ders6", axis=1 , inplace=True) #inplace parametresi TRUE değeri atandığında dataframe içinde o işlemi yapıyor ve kaydediyor. Yoksa yukarıda yapıldığı gibi bir değişkene atanmalı.

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      7      0      6      2      3     18
# Ayşe        5      7      5      4      4     15
# Elif        3      8      1      0      5      3
# Melike      9      9      3      3      6      9

# %%
new_df.drop("Melike", axis=0)
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      7      0      6      2      3     18
# Ayşe        5      7      5      4      4     15
# Elif        3      8      1      0      5      3

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      7      0      6      2      3     18
# Ayşe        5      7      5      4      4     15
# Elif        3      8      1      0      5      3
# Melike      9      9      3      3      6      9

# %%
new_df.loc["Mehmet"] = 15

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      7      0      6      2      3     18
# Ayşe        5      7      5      4      4     15
# Elif        3      8      1      0      5      3
# Melike      9      9      3      3      6      9
# Mehmet     15     15     15     15     15     15

# %%
new_df.loc["Ahmet"] = [3,5,7,8,9,3]

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      7      0      6      2      3     18
# Ayşe        5      7      5      4      4     15
# Elif        3      8      1      0      5      3
# Melike      9      9      3      3      6      9
# Mehmet     15     15     15     15     15     15
# Ahmet       3      5      7      8      9      3

# %%
new_df.iloc[0,0:1] = 8

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      8      0      6      2      3     18
# Ayşe        5      7      5      4      4     15
# Elif        3      8      1      0      5      3
# Melike      9      9      3      3      6      9
# Mehmet     15     15     15     15     15     15
# Ahmet       3      5      7      8      9      3

# %%
new_df.loc["Ahmet","Ders1"] = 5

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      8      0      6      2      3     18
# Ayşe        5      7      5      4      4     15
# Elif        3      8      1      0      5      3
# Melike      9      9      3      3      6      9
# Mehmet     15     15     15     15     15     15
# Ahmet       5      5      7      8      9      3

# %%
new_df.loc["Mehmet","Ders1"] = 6

# %%
new_df
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      8      0      6      2      3     18
# Ayşe        5      7      5      4      4     15
# Elif        3      8      1      0      5      3
# Melike      9      9      3      3      6      9
# Mehmet      6     15     15     15     15     15
# Ahmet       5      5      7      8      9      3

# %% [markdown]
# **Filtrelemeler**

# %%
bool_frame = new_df > 5

# %%
bool_frame
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan   True  False   True  False  False   True
# Ayşe    False   True  False  False  False   True
# Elif    False   True  False  False  False  False
# Melike   True   True  False  False   True   True
# Mehmet   True   True   True   True   True   True
# Ahmet   False  False   True   True   True  False

# %%
new_df[new_df > 5]
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan    8.0    NaN    6.0    NaN    NaN   18.0
# Ayşe      NaN    7.0    NaN    NaN    NaN   15.0
# Elif      NaN    8.0    NaN    NaN    NaN    NaN
# Melike    9.0    9.0    NaN    NaN    6.0    9.0
# Mehmet    6.0   15.0   15.0   15.0   15.0   15.0
# Ahmet     NaN    NaN    7.0    8.0    9.0    NaN

# %%
new_df[new_df["Ders1"]>5]
# Out:
#         Ders1  Ders2  Ders3  Ders4  Ders5  Ders7
# Gürhan      8      0      6      2      3     18
# Melike      9      9      3      3      6      9
# Mehmet      6     15     15     15     15     15

# %% [markdown]
# **.csv dosya okuma, gerçek dataları içeri alma. **

# %%
notlar_df = pd.read_csv("/content/ECS_Veri_Bilimi_Yapay_Zeka_notlar_eksik_new.csv")

# %%
notlar_df
# Out:
#     ogrenci_no  calisma_saati  devamsizlik  sinav1  sinav2  sinav3  proje
# 0          101           18.0          1.0    81.0    84.0    83.0   75.0
# 1          102            9.0          7.0    59.0    52.0    60.0    NaN
# 2          103            NaN          7.0    77.0    62.0    74.0   69.0
# 3          104            5.0         12.0    63.0    51.0    59.0   40.0
# 4          105           10.0          7.0     NaN    63.0    70.0   74.0
# 5          106            6.0          NaN    55.0    51.0    51.0   63.0
# 6          107            6.0         99.0    61.0    57.0    50.0   48.0
# 7          108           13.0          7.0    77.0     NaN    71.0   73.0
# 8          109           13.0          7.0    73.0    73.0    70.0    NaN
# 9          110            NaN          9.0    65.0    55.0    54.0   65.0
# 10         111           23.0          0.0   100.0   100.0   100.0  100.0
# 11         112            3.0         10.0    52.0    57.0     NaN   61.0
# ...

# %%
notlar_df.head() # data frame'in ilk 5 verisini getirir.
# Out:
#    ogrenci_no  calisma_saati  devamsizlik  sinav1  sinav2  sinav3  proje
# 0         101           18.0          1.0    81.0    84.0    83.0   75.0
# 1         102            9.0          7.0    59.0    52.0    60.0    NaN
# 2         103            NaN          7.0    77.0    62.0    74.0   69.0
# 3         104            5.0         12.0    63.0    51.0    59.0   40.0
# 4         105           10.0          7.0     NaN    63.0    70.0   74.0

# %%
notlar_df.tail() # data frame'in son 5 verisini getirir.
# Out:
#     ogrenci_no  calisma_saati  devamsizlik  sinav1  sinav2  sinav3  proje
# 27         128           12.0          9.0    63.0    70.0    65.0   70.0
# 28         129           12.0          7.0    72.0     NaN    61.0   63.0
# 29         130           12.0          5.0    75.0    64.0    76.0   63.0
# 30         104            5.0         12.0    63.0    51.0    59.0   40.0
# 31         113            7.0          7.0    62.0    49.0    61.0   63.0

# %%
notlar_df.describe() # dataframe hakkında temel istatistiksel verileri veriyor.
# Out:
#        ogrenci_no  calisma_saati  devamsizlik      sinav1      sinav2  \
# count   32.000000      29.000000    30.000000   29.000000   28.000000
# mean   115.062500      11.448276     9.166667   70.379310   97.785714
# std      8.761858       5.060958    17.302747   12.462555  167.596154
# min    101.000000       3.000000     0.000000   52.000000   49.000000
# 25%    107.750000       7.000000     4.000000   62.000000   54.750000
# 50%    114.500000      11.000000     7.000000   66.000000   63.500000
# 75%    122.250000      15.000000     9.000000   78.000000   78.500000
# max    130.000000      23.000000    99.000000  100.000000  950.000000
#
#            sinav3       proje
# count   29.000000   28.000000
# mean    69.793103   66.607143
# std     13.467897   14.345832
# min     50.000000   40.000000
# 25%     59.000000   62.500000
# 50%     70.000000   65.000000
# 75%     79.000000   75.000000
# max    100.000000  100.000000

# %%
notlar_df.shape # satır ve sütun sayıları
# Out:
# (32, 7)

# %%
notlar_df.columns
# Out:
# Index(['ogrenci_no', 'calisma_saati', 'devamsizlik', 'sinav1', 'sinav2',
#        'sinav3', 'proje'],
#       dtype='object')

# %%
notlar_df.info()# Dataframe Sütunları ile ilgili genel bilgi.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ogrenci_no     32 non-null     int64
#  1   calisma_saati  29 non-null     float64
#  2   devamsizlik    30 non-null     float64
#  3   sinav1         29 non-null     float64
#  4   sinav2         28 non-null     float64
#  5   sinav3         29 non-null     float64
#  6   proje          28 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 1.9 KB

# %%
notlar_df.isna() # boş değerler ile ilgili boşta true
# Out:
#     ogrenci_no  calisma_saati  devamsizlik  sinav1  sinav2  sinav3  proje
# 0        False          False        False   False   False   False  False
# 1        False          False        False   False   False   False   True
# 2        False           True        False   False   False   False  False
# 3        False          False        False   False   False   False  False
# 4        False          False        False    True   False   False  False
# 5        False          False         True   False   False   False  False
# 6        False          False        False   False   False   False  False
# 7        False          False        False   False    True   False  False
# 8        False          False        False   False   False   False   True
# 9        False           True        False   False   False   False  False
# 10       False          False        False   False   False   False  False
# 11       False          False        False   False   False    True  False
# ...

# %%
notlar_df["sinav1"].isna() # boş değerler ile ilgili sütun seçtik. boşsa true
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# Name: sinav1, dtype: bool

# %%
notlar_df
# Out:
#     ogrenci_no  calisma_saati  devamsizlik  sinav1  sinav2  sinav3  proje
# 0          101           18.0          1.0    81.0    84.0    83.0   75.0
# 1          102            9.0          7.0    59.0    52.0    60.0    NaN
# 2          103            NaN          7.0    77.0    62.0    74.0   69.0
# 3          104            5.0         12.0    63.0    51.0    59.0   40.0
# 4          105           10.0          7.0     NaN    63.0    70.0   74.0
# 5          106            6.0          NaN    55.0    51.0    51.0   63.0
# 6          107            6.0         99.0    61.0    57.0    50.0   48.0
# 7          108           13.0          7.0    77.0     NaN    71.0   73.0
# 8          109           13.0          7.0    73.0    73.0    70.0    NaN
# 9          110            NaN          9.0    65.0    55.0    54.0   65.0
# 10         111           23.0          0.0   100.0   100.0   100.0  100.0
# 11         112            3.0         10.0    52.0    57.0     NaN   61.0
# ...

# %%
notlar_df.drop("proje", axis=1)
# Out:
#     ogrenci_no  calisma_saati  devamsizlik  sinav1  sinav2  sinav3
# 0          101           18.0          1.0    81.0    84.0    83.0
# 1          102            9.0          7.0    59.0    52.0    60.0
# 2          103            NaN          7.0    77.0    62.0    74.0
# 3          104            5.0         12.0    63.0    51.0    59.0
# 4          105           10.0          7.0     NaN    63.0    70.0
# 5          106            6.0          NaN    55.0    51.0    51.0
# 6          107            6.0         99.0    61.0    57.0    50.0
# 7          108           13.0          7.0    77.0     NaN    71.0
# 8          109           13.0          7.0    73.0    73.0    70.0
# 9          110            NaN          9.0    65.0    55.0    54.0
# 10         111           23.0          0.0   100.0   100.0   100.0
# 11         112            3.0         10.0    52.0    57.0     NaN
# 12         113            7.0          7.0    62.0    49.0    61.0
# ...

# %%
notlar_df
# Out:
#     ogrenci_no  calisma_saati  devamsizlik  sinav1  sinav2  sinav3  proje
# 0          101           18.0          1.0    81.0    84.0    83.0   75.0
# 1          102            9.0          7.0    59.0    52.0    60.0    NaN
# 2          103            NaN          7.0    77.0    62.0    74.0   69.0
# 3          104            5.0         12.0    63.0    51.0    59.0   40.0
# 4          105           10.0          7.0     NaN    63.0    70.0   74.0
# 5          106            6.0          NaN    55.0    51.0    51.0   63.0
# 6          107            6.0         99.0    61.0    57.0    50.0   48.0
# 7          108           13.0          7.0    77.0     NaN    71.0   73.0
# 8          109           13.0          7.0    73.0    73.0    70.0    NaN
# 9          110            NaN          9.0    65.0    55.0    54.0   65.0
# 10         111           23.0          0.0   100.0   100.0   100.0  100.0
# 11         112            3.0         10.0    52.0    57.0     NaN   61.0
# ...

# %%
notlar_df.fillna(10) #tüm boşlukları "10 sayısı ile doldur." neden 10 çünkü o değeri atadık bir önemi yok. 20 30 50 olabilir.
# Out:
#     ogrenci_no  calisma_saati  devamsizlik  sinav1  sinav2  sinav3  proje
# 0          101           18.0          1.0    81.0    84.0    83.0   75.0
# 1          102            9.0          7.0    59.0    52.0    60.0   10.0
# 2          103           10.0          7.0    77.0    62.0    74.0   69.0
# 3          104            5.0         12.0    63.0    51.0    59.0   40.0
# 4          105           10.0          7.0    10.0    63.0    70.0   74.0
# 5          106            6.0         10.0    55.0    51.0    51.0   63.0
# 6          107            6.0         99.0    61.0    57.0    50.0   48.0
# 7          108           13.0          7.0    77.0    10.0    71.0   73.0
# 8          109           13.0          7.0    73.0    73.0    70.0   10.0
# 9          110           10.0          9.0    65.0    55.0    54.0   65.0
# 10         111           23.0          0.0   100.0   100.0   100.0  100.0
# 11         112            3.0         10.0    52.0    57.0    10.0   61.0
# ...

# %%
notlar_df
# Out:
#     ogrenci_no  calisma_saati  devamsizlik  sinav1  sinav2  sinav3  proje
# 0          101           18.0          1.0    81.0    84.0    83.0   75.0
# 1          102            9.0          7.0    59.0    52.0    60.0    NaN
# 2          103            NaN          7.0    77.0    62.0    74.0   69.0
# 3          104            5.0         12.0    63.0    51.0    59.0   40.0
# 4          105           10.0          7.0     NaN    63.0    70.0   74.0
# 5          106            6.0          NaN    55.0    51.0    51.0   63.0
# 6          107            6.0         99.0    61.0    57.0    50.0   48.0
# 7          108           13.0          7.0    77.0     NaN    71.0   73.0
# 8          109           13.0          7.0    73.0    73.0    70.0    NaN
# 9          110            NaN          9.0    65.0    55.0    54.0   65.0
# 10         111           23.0          0.0   100.0   100.0   100.0  100.0
# 11         112            3.0         10.0    52.0    57.0     NaN   61.0
# ...

# %%
notlar_df.mean() # Genel Sütun ortalamaları
# Out:
# ogrenci_no       115.062500
# calisma_saati     11.448276
# devamsizlik        9.166667
# sinav1            70.379310
# sinav2            97.785714
# sinav3            69.793103
# proje             66.607143
# dtype: float64

# %%
notlar_df.fillna(notlar_df.mean()) #Tüm boşlukları sütun ortalamaları ile doldur.
# Out:
#     ogrenci_no  calisma_saati  devamsizlik     sinav1      sinav2      sinav3  \
# 0          101      18.000000     1.000000   81.00000   84.000000   83.000000
# 1          102       9.000000     7.000000   59.00000   52.000000   60.000000
# 2          103      11.448276     7.000000   77.00000   62.000000   74.000000
# 3          104       5.000000    12.000000   63.00000   51.000000   59.000000
# 4          105      10.000000     7.000000   70.37931   63.000000   70.000000
# 5          106       6.000000     9.166667   55.00000   51.000000   51.000000
# 6          107       6.000000    99.000000   61.00000   57.000000   50.000000
# 7          108      13.000000     7.000000   77.00000   97.785714   71.000000
# 8          109      13.000000     7.000000   73.00000   73.000000   70.000000
# 9          110      11.448276     9.000000   65.00000   55.000000   54.000000
# 10         111      23.000000     0.000000  100.00000  100.000000  100.000000
# ...

# %%
notlar_df.max() #sütun maximum değerleri
# Out:
# ogrenci_no       130.0
# calisma_saati     23.0
# devamsizlik       99.0
# sinav1           100.0
# sinav2           950.0
# sinav3           100.0
# proje            100.0
# dtype: float64

# %%
notlar_df.min() #sütun minumum değerleri
# Out:
# ogrenci_no       101.0
# calisma_saati      3.0
# devamsizlik        0.0
# sinav1            52.0
# sinav2            49.0
# sinav3            50.0
# proje             40.0
# dtype: float64

# %%
notlar_df
# Out:
#     ogrenci_no  calisma_saati  devamsizlik  sinav1  sinav2  sinav3  proje
# 0          101           18.0          1.0    81.0    84.0    83.0   75.0
# 1          102            9.0          7.0    59.0    52.0    60.0    NaN
# 2          103            NaN          7.0    77.0    62.0    74.0   69.0
# 3          104            5.0         12.0    63.0    51.0    59.0   40.0
# 4          105           10.0          7.0     NaN    63.0    70.0   74.0
# 5          106            6.0          NaN    55.0    51.0    51.0   63.0
# 6          107            6.0         99.0    61.0    57.0    50.0   48.0
# 7          108           13.0          7.0    77.0     NaN    71.0   73.0
# 8          109           13.0          7.0    73.0    73.0    70.0    NaN
# 9          110            NaN          9.0    65.0    55.0    54.0   65.0
# 10         111           23.0          0.0   100.0   100.0   100.0  100.0
# 11         112            3.0         10.0    52.0    57.0     NaN   61.0
# ...

# %%
notlar_df["sinav1"] = notlar_df["sinav1"].fillna(notlar_df["sinav1"].mean() ) # tek bir sütunun eksik verilerini doldurma.

# %%
notlar_df
# Out:
#     ogrenci_no  calisma_saati  devamsizlik     sinav1  sinav2  sinav3  proje
# 0          101           18.0          1.0   81.00000    84.0    83.0   75.0
# 1          102            9.0          7.0   59.00000    52.0    60.0    NaN
# 2          103            NaN          7.0   77.00000    62.0    74.0   69.0
# 3          104            5.0         12.0   63.00000    51.0    59.0   40.0
# 4          105           10.0          7.0   70.37931    63.0    70.0   74.0
# 5          106            6.0          NaN   55.00000    51.0    51.0   63.0
# 6          107            6.0         99.0   61.00000    57.0    50.0   48.0
# 7          108           13.0          7.0   77.00000     NaN    71.0   73.0
# 8          109           13.0          7.0   73.00000    73.0    70.0    NaN
# 9          110            NaN          9.0   65.00000    55.0    54.0   65.0
# 10         111           23.0          0.0  100.00000   100.0   100.0  100.0
# ...

# %% [markdown]
# **CONCAT Kavramı - MERGE Kavramı**

# %%
df = pd.read_csv("/content/5. Ders - concat_data1.csv")

# %%
df
# Out:
#    Employee_ID    Name Department
# 0            1   Emp_1    Finance
# 1            2   Emp_2  Marketing
# 2            3   Emp_3         HR
# 3            4   Emp_4    Finance
# 4            5   Emp_5    Finance
# 5            6   Emp_6  Marketing
# 6            7   Emp_7         HR
# 7            8   Emp_8         HR
# 8            9   Emp_9    Finance
# 9           10  Emp_10         IT

# %%
df2 = pd.read_csv("/content/5. Ders - concat_data2.csv")

# %%
df2
# Out:
#    Employee_ID    Name Department
# 0           11  Emp_11    Finance
# 1           12  Emp_12    Finance
# 2           13  Emp_13    Finance
# 3           14  Emp_14    Finance
# 4           15  Emp_15  Marketing
# 5           16  Emp_16         HR
# 6           17  Emp_17  Marketing
# 7           18  Emp_18  Marketing
# 8           19  Emp_19  Marketing
# 9           20  Emp_20    Finance

# %%
df_concat = pd.concat([df,df2], ignore_index=True)

# %%
df_concat
# Out:
#     Employee_ID    Name Department
# 0             1   Emp_1    Finance
# 1             2   Emp_2  Marketing
# 2             3   Emp_3         HR
# 3             4   Emp_4    Finance
# 4             5   Emp_5    Finance
# 5             6   Emp_6  Marketing
# 6             7   Emp_7         HR
# 7             8   Emp_8         HR
# 8             9   Emp_9    Finance
# 9            10  Emp_10         IT
# 10           11  Emp_11    Finance
# 11           12  Emp_12    Finance
# 12           13  Emp_13    Finance
# 13           14  Emp_14    Finance
# 14           15  Emp_15  Marketing
# 15           16  Emp_16         HR
# 16           17  Emp_17  Marketing
# 17           18  Emp_18  Marketing
# 18           19  Emp_19  Marketing
# 19           20  Emp_20    Finance

# %%
df3 = pd.read_csv("/content/5. Ders - merge_data1.csv")

# %%
df3
# Out:
#    Employee_ID    Name Department
# 0            1   Emp_1         IT
# 1            2   Emp_2         HR
# 2            3   Emp_3         IT
# 3            4   Emp_4  Marketing
# 4            5   Emp_5  Marketing
# 5            6   Emp_6         IT
# 6            7   Emp_7         IT
# 7            8   Emp_8         IT
# 8            9   Emp_9  Marketing
# 9           10  Emp_10  Marketing

# %%
df4 = pd.read_csv("/content/5. Ders - merge_data2.csv")

# %%
df4
# Out:
#    Employee_ID  Salary  Experience
# 0            5   55658           3
# 1            1  114478           5
# 2           12   48431          19
# 3           10   32747           7
# 4            6   89150           9
# 5           13   95725           7
# 6            9   65773           4
# 7           11   86886          18

# %%
df_merge = pd.merge(df3, df4, on="Employee_ID", how="inner")

# %%
df_merge
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 0            1   Emp_1         IT  114478           5
# 1            5   Emp_5  Marketing   55658           3
# 2            6   Emp_6         IT   89150           9
# 3            9   Emp_9  Marketing   65773           4
# 4           10  Emp_10  Marketing   32747           7

# %%
df_merge2 = pd.merge(df3, df4, on="Employee_ID", how="outer")

# %%
df_merge2
# Out:
#     Employee_ID    Name Department    Salary  Experience
# 0             1   Emp_1         IT  114478.0         5.0
# 1             2   Emp_2         HR       NaN         NaN
# 2             3   Emp_3         IT       NaN         NaN
# 3             4   Emp_4  Marketing       NaN         NaN
# 4             5   Emp_5  Marketing   55658.0         3.0
# 5             6   Emp_6         IT   89150.0         9.0
# 6             7   Emp_7         IT       NaN         NaN
# 7             8   Emp_8         IT       NaN         NaN
# 8             9   Emp_9  Marketing   65773.0         4.0
# 9            10  Emp_10  Marketing   32747.0         7.0
# 10           11     NaN        NaN   86886.0        18.0
# 11           12     NaN        NaN   48431.0        19.0
# 12           13     NaN        NaN   95725.0         7.0

# %%
df_merge3 = pd.merge(df3, df4, on="Employee_ID", how="left")

# %%
df_merge3
# Out:
#    Employee_ID    Name Department    Salary  Experience
# 0            1   Emp_1         IT  114478.0         5.0
# 1            2   Emp_2         HR       NaN         NaN
# 2            3   Emp_3         IT       NaN         NaN
# 3            4   Emp_4  Marketing       NaN         NaN
# 4            5   Emp_5  Marketing   55658.0         3.0
# 5            6   Emp_6         IT   89150.0         9.0
# 6            7   Emp_7         IT       NaN         NaN
# 7            8   Emp_8         IT       NaN         NaN
# 8            9   Emp_9  Marketing   65773.0         4.0
# 9           10  Emp_10  Marketing   32747.0         7.0

# %%
df_merge4 = pd.merge(df3, df4, on="Employee_ID", how="right")

# %%
df_merge4
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 0            5   Emp_5  Marketing   55658           3
# 1            1   Emp_1         IT  114478           5
# 2           12     NaN        NaN   48431          19
# 3           10  Emp_10  Marketing   32747           7
# 4            6   Emp_6         IT   89150           9
# 5           13     NaN        NaN   95725           7
# 6            9   Emp_9  Marketing   65773           4
# 7           11     NaN        NaN   86886          18
