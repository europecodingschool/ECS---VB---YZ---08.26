# %% [markdown]
# <a href="https://colab.research.google.com/github/europecodingschool/ECS---VB---YZ---08.26/blob/main/VB_YZ_Ders_11_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SINIFLANDIRMA
#
#
# LOJİSTİK REGRESYON
#
# Neden Doğrusal Regresyon Kullanmıyoruz?
#
#
# *   Çıktı Sınır Tanımaz
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2- Tek Bir Aykırı Değer bile algoritmayı saptırır. (Doğrusal regresyonda aykırı değerler sapmaya yok açıyor.
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/kanser_veriseti_basit.csv")

# %%
df.head() # data setimde tümör boyutu ve kanser mi değil mi verisi var. Hedefim yeni bir tümör boyu gördüğümde kanser mi değil mi tahmin etmek.
# Out:
#    Tumor_Boyutu  Kanser_Mi
# 0          1.96          0
# 1          5.03          1
# 2          6.02          1
# 3          4.53          1
# 4          1.64          0
