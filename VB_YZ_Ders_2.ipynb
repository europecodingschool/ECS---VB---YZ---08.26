# %% [markdown]
# <a href="https://colab.research.google.com/github/europecodingschool/ECS---VB---YZ---08.26/blob/main/VB_YZ_Ders_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3 + 5
# Out:
# 8

# %%
800 / 7
# Out:
# 114.28571428571429

# %%
5 * 5 * 5
# Out:
# 125

# %%
5*5*5
# Out:
# 125

# %% [markdown]
# Değişken

# %%
age = 20

# %%
age
# Out:
# 20

# %%
age + 5
# Out:
# 25

# %%
age * 15 + 5
# Out:
# 305

# %%
age + age
# Out:
# 40

# %%
age = 30

# %%
age
# Out:
# 30

# %%
age + 10
# Out:
# 40

# %%
yas = 20

# %%
abi = 30

# %%
kardes = 15

# %%
age + yas + abi + kardes
# Out:
# 95

# %%
50 / 5  #data type
# Out:
# 10.0

# %%
40 * 3
# Out:
# 120

# %%
800 / 7
# Out:
# 114.28571428571429

# %%
# integer - int

# %%
type(10)
# Out:
# int

# %%
type(10 * 5)
# Out:
# int

# %%
type(age)
# Out:
# int

# %%
x = -100

# %%
type(x)
# Out:
# int

# %%
y = 800 / 7

# %%
y
# Out:
# 114.28571428571429

# %%
type(y) # floating point - float
# Out:
# float

# %%
y + x
# Out:
# 14.285714285714292

# %%
type(y + x)
# Out:
# float

# %%
z = x + y

# %%
z
# Out:
# 14.285714285714292

# %%
type(z)
# Out:
# float

# %%
myFloat = 3.1456

# %%
my_float = 5.16

# %%
type(myFloat)
# Out:
# float

# %%
#camelCase
#snake_case

# %%
5 * 5 * 5 * 5
# Out:
# 625

# %%
5 ** 4 # üslü ifadeler
# Out:
# 625

# %%
10 / 4
# Out:
# 2.5

# %%
10 % 4 # kalanı verir
# Out:
# 2
