# %% [markdown]
# <a href="https://colab.research.google.com/github/europecodingschool/ECS---VB---YZ---08.26/blob/main/VB_YZ_Ders_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3 + 5
# Out:
# 8

# %%
800 / 7
# Out:
# 114.28571428571429

# %%
5 * 5 * 5
# Out:
# 125

# %%
5*5*5
# Out:
# 125

# %% [markdown]
# Değişken

# %%
age = 20

# %%
age
# Out:
# 20

# %%
age + 5
# Out:
# 25

# %%
age * 15 + 5
# Out:
# 305

# %%
age + age
# Out:
# 40

# %%
age = 30

# %%
age
# Out:
# 30

# %%
age + 10
# Out:
# 40

# %%
yas = 20

# %%
abi = 30

# %%
kardes = 15

# %%
age + yas + abi + kardes
# Out:
# 95

# %%
50 / 5  #data type
# Out:
# 10.0

# %%
40 * 3
# Out:
# 120

# %%
800 / 7
# Out:
# 114.28571428571429

# %%
# integer - int

# %%
type(10)
# Out:
# int

# %%
type(10 * 5)
# Out:
# int

# %%
type(age)
# Out:
# int

# %%
x = -100

# %%
type(x)
# Out:
# int

# %%
y = 800 / 7

# %%
y
# Out:
# 114.28571428571429

# %%
type(y) # floating point - float
# Out:
# float

# %%
y + x
# Out:
# 14.285714285714292

# %%
type(y + x)
# Out:
# float

# %%
z = x + y

# %%
z
# Out:
# 14.285714285714292

# %%
type(z)
# Out:
# float

# %%
myFloat = 3.1456

# %%
my_float = 5.16

# %%
type(myFloat)
# Out:
# float

# %%
#camelCase
#snake_case

# %%
5 * 5 * 5 * 5
# Out:
# 625

# %%
5 ** 4 # üslü ifadeler
# Out:
# 625

# %%
10 / 4
# Out:
# 2.5

# %%
10 % 4 # kalanı verir
# Out:
# 2

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
print("Merhaba Dünya")
# Out:
# Merhaba Dünya

# %%
name = "Gürhan"

# %%
type(name)  # str - strings
# Out:
# str

# %%
name2 = 'Gürhan'

# %%
name2
# Out:
# 'Gürhan'

# %%
"Türkiye'nin Başkenti Ankara'dır."
# Out:
# "Türkiye'nin Başkenti Ankara'dır."

# %%
name.capitalize()
# Out:
# 'Gürhan'

# %%
help(name.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
isim = "gürhan temiz"

# %%
isim.capitalize()
# Out:
# 'Gürhan temiz'

# %%
x = "10"

# %%
x
# Out:
# '10'

# %%
# - (x + 5) -- iki farklı değişken tipi matematiksel işleme girdiği için hata verdi. int ve str toplanmaya çalışıldı.
# "10" tırnak içinde yazılan sayılar da str dir.

# %%
type(x)
# Out:
# str

# %%
isim
# Out:
# 'gürhan temiz'

# %%
isim.upper()
# Out:
# 'GÜRHAN TEMIZ'

# %%
isim
# Out:
# 'gürhan temiz'

# %%
buyuk_isim = print(isim.upper())
# Out:
# GÜRHAN TEMIZ

# %%
len(isim) # uzunluk - length
# Out:
# 12

# %%
name = "sadık"

# %%
len(name)
# Out:
# 5

# %% [markdown]
# # **INDEX **

# %%
myString = "hello phyton"

# %%
len(myString)
# Out:
# 12

# %%
myString[1]
# Out:
# 'e'

# %%
myString[6]
# Out:
# 'p'

# %%
myString[8]
# Out:
# 'y'

# %%
ad = "Hüseyin Gürhan Temiz"

# %%
ad
# Out:
# 'Hüseyin Gürhan Temiz'

# %%
len(ad)
# Out:
# 20

# %%
ad[6]
# Out:
# 'n'

# %%
ad[15]
# Out:
# 'T'

# %%
len(ad) - 1
# Out:
# 19

# %%
ad[len(ad)-1]
# Out:
# 'z'

# %%
ad[-1]
# Out:
# 'z'

# %%
barcode = "ABC123456789"

# %%
barcode[0]
# Out:
# 'A'

# %%
barcode[3]
# Out:
# '1'

# %%
barcode[0] + barcode[3] + barcode[6]
# Out:
# 'A14'

# %%
barcode[0] + barcode[1] + barcode[2]
# Out:
# 'ABC'

# %%
#slicing, starting index, stopping index, stepping size

# %%
barcode
# Out:
# 'ABC123456789'

# %%
barcode[::]
# Out:
# 'ABC123456789'

# %%
barcode[3::]
# Out:
# '123456789'

# %%
barcode[5::]
# Out:
# '3456789'

# %%
barcode[5:8:]
# Out:
# '345'

# %%
barcode[1:5:]
# Out:
# 'BC12'

# %%
barcode[0:9:2]
# Out:
# 'AC246'

# %%
barcode[0:7:2]
# Out:
# 'AC24'

# %%
barcode = "ABCDE123123987" # tek satırda "DE" yi alın.

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode.split()
# Out:
# ['ABCDE123123987']

# %%
name = "Gürhan Temiz"

# %%
name.split()
# Out:
# ['Gürhan', 'Temiz']

# %%
type(name.split())
# Out:
# list

# %%
#List - Listeler

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x = 15
y = 25
z = 35

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [15, 25, 35]

# %%
myList[0]
# Out:
# 15

# %%
len(myList)
# Out:
# 3

# %%
myList.append(30)

# %%
myList
# Out:
# [15, 25, 35, 50, 50, 40, 30]

# %%
len(myList)
# Out:
# 7

# %%
yas = input("yasınızı giriniz:")
# Out:
# yasınızı giriniz:20

# %%
yas
# Out:
# '20'

# %%
mixList = ["gürhan",15,25]

# %%
mixList
# Out:
# ['gürhan', 15, 25]

# %%
mixList[0]
# Out:
# 'gürhan'

# %%
type(myList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [40,50,60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
type(mixList[0])
# Out:
# str

# %%
type(mixList[1])
# Out:
# int

# %%
myBestlist = [10,20,3.15,"furkan",[1,2,3]]

# %%
myBestlist
# Out:
# [10, 20, 3.15, 'furkan', [1, 2, 3]]

# %%
len(myBestlist)
# Out:
# 5

# %%
myBestlist[0]
# Out:
# 10

# %%
myBestlist[3]
# Out:
# 'furkan'

# %%
myBestlist[4]
# Out:
# [1, 2, 3]

# %%
type(myBestlist[0])
# Out:
# int

# %%
type(myBestlist[3])
# Out:
# str

# %%
type(myBestlist[4])
# Out:
# list

# %%
myBestlist  # 4. indexdeki 3 e ulaşmak istiyorum.
# Out:
# [10, 20, 3.15, 'furkan', [1, 2, 3]]

# %%
myBestlist[4][2]
# Out:
# 3

# %%
mySmalllist = myBestlist[4]

# %%
mySmalllist
# Out:
# [1, 2, 3]

# %%
mySmalllist[2]
# Out:
# 3

# %%
mySmalllist[0]
# Out:
# 1

# %%
myBestlist[-1][-1]
# Out:
# 3

# %%
fruit_list = ["banana","apple"]

# %%
calorie_list = [200, 100]

# %%
fruit_list[1]
# Out:
# 'apple'

# %%
calorie_list[1]
# Out:
# 100

# %%
fitness_dic = {"banana":200,"apple":100}

# %%
type(fitness_dic)
# Out:
# dict

# %%
fitness_dic["banana"]
# Out:
# 200

# %%
fitness_dic["apple"]
# Out:
# 100
